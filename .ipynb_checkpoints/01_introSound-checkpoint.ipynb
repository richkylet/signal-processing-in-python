# %% [markdown]
# # Introduction to sound waves

# %% [markdown]
# ## Waves
#
# ![title](img/wave.jpg)
#
# Because sound is a wave, similar to many other physical phenomena, the representative analysis conducted in the following sections can be applied to other types of waves. However, it should be noted that sound is a pressure wave, a mechanical wave that results from the back and forth vibration of the particles of the medium through which it is moving.
#
# For sound waves, a pure tone can be represented by a sine wave that has a frequency in units of Hertz (cycles per second) and amplitude (related to how 'loud' the sound is). First, we can consider a sine wave with a frequency of 2 Hz and amplitude of 3 arbitrary units (apply appropriate units here) shown as a function of time (time domain) below:

# %%
# before we do that, lets load packages/tools we will need
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy

# %% [markdown]
# Plotting helper:

# %%
def setup_graph(title='', x_label='', y_label='', fig_size=None):
    fig = plt.figure()
    if fig_size != None:
        fig.set_size_inches(fig_size[0], fig_size[1])
    ax = fig.add_subplot(111)
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    plt.grid()

# %% [markdown]
# Signal generator:

# %%
# init and self
class Signal:
    def __init__(self, amp, freq, tmax, fs):
        self.a = amp
        self.f = freq
        self.t = np.linspace(0, tmax, tmax*fs)
        self.s = [self.a*np.sin(2 * np.pi * self.f * i) for i in self.t]

# %% [markdown]
# Generate and plot a time-domain signal (signal amplitude as a function of time):

# %%
# use signal generator
y = Signal(3.0, 2, 3, 40)
# plot
setup_graph(x_label='time (in seconds)', y_label='amplitude', title='time domain')
plt.plot(y.t,y.s,'b.-')

# %% [markdown]
# However, most sounds are not recorded or created as pure tones, and are instead the addition of multiple sound waves of different frequencies and amplitudes, and likely contain some noise (due to background, electronics, etc). These multiple signals are superimposed (added together to form a single wave), sometimes constructively and sometimes destructively, as illustrated below. Note the distortion to the primary tone (blue curve) after the addition of noise and other low amplitude waves (superimposed wave is red, original signal in blue).

# %%
y2 = Signal(3.0/2, 2.0/2,    3.0, 40)  # tone 2 (half amplitude, half freq)
y3 = Signal(3.0/4, 2.0/1.25, 3.0, 40)  # tone 3 (1/4 amplitude, 1.25 freq)
yn = np.random.normal(0,3.0/10,len(y2.s))  # random background/electronic noise

# the superpositioned wave:
y1 = [y.s,y2.s,y3.s,yn]
y0 = [sum(x) for x in zip(*y1)]

setup_graph(x_label='time (in seconds)', y_label='amplitude', title='time domain')
plt.plot(y.t, yn,  'k:', label = 'noise')
plt.plot(y.t, y3.s,'g--', label = 'tone 3')
plt.plot(y.t, y2.s,'c--', label = 'tone 2')
plt.plot(y.t, y.s,'b-', label = 'tone 1 (original signal)')
plt.plot(y.t, y0, '-r',label = 'superimposed wave')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# We can see that some parts of the wave are interfered with negatively and some positively, depending on the phase of the wave. That is, there is phase effects (cancelation or superposition) in the final cummulative wave.
#
# This effect can be illustrated by considering two waves that are 180 degrees out of phase and added together to produce a cummulative wave that has zero amplitude:

# %%
t = y.t
y3 = 3*np.sin(2 * np.pi * 2 * y.t)   # tone 3
y4 = -3*np.sin(2 * np.pi * 2 * y.t)# tone 4

setup_graph(x_label='time (in seconds)', y_label='amplitude', title='time domain')
plt.plot(t, y3,'r:', label = 'tone 3')
plt.plot(t, y4,'b--', label = 'tone 4')
plt.plot(t, y3+y4,'m-', label = 'tone 3 + tone 4')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# ## EXAMPLE: a real sound in the time domain is the right whale call measured with some background noise:
#
# One signal is known to be a whale call. The other is known to be noise. How would one distinguish these two signals without a priori knowledge?

# %%
import pandas as pd
import seaborn as sns 
import aifc


pd.options.mode.chained_assignment = None 

# training data
fp = '/Users/KRich/GitHub/data/whale/data/'
trainData = pd.read_csv(fp + 'train.csv')

# indices in trainData that contain a whale call:
iWhaleCall   = [i for i, x in enumerate(trainData.label) if x == 1]
iNoWhaleCall = [i for i, x in enumerate(trainData.label) if x == 0]

clips = list(trainData.clip_name)

# data ====================================

# data file names for example data
posFN =  fp+'train/train'+str(iWhaleCall[200])+'.aiff'
negFN =  fp+'train/train'+str(iNoWhaleCall[100])+'.aiff'

# open data files and sort
posSig = aifc.open(posFN, 'r')
negSig = aifc.open(negFN, 'r')

posStrSig = posSig.readframes(posSig.getnframes())
pos_y = np.fromstring(posStrSig,np.short).byteswap()

negStrSig = negSig.readframes(negSig.getnframes())
neg_y = np.fromstring(negStrSig,np.short).byteswap()

# frame rate
fs = posSig.getframerate()

# number of frames
N = posSig.getnframes()

# values
ts = 1.0/fs
t = np.arange(0,2,ts)

setup_graph(x_label='time (in seconds)', y_label='amplitude', title='time domain')
plt.plot(t, neg_y,'b--', label = 'Not whale (noise)')
plt.plot(t, pos_y,'r:', label = 'whale')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# #### NOTE:
# For this example of a right whale call (red), it is very complicated to distinguish it from a random noise signal (blue). One approach we can take to distinguish these signals is to look at their corresponding spectral contents in the frequency-domain.
